# %%
import pandas as pd
import datetime

# %%
crashes=pd.read_csv('NYC_Car_Crash_Clean')
# Out:
# C:\Users\789\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (4,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
crashes.head()
# Out:
#    Unnamed: 0        DATE   TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0           0  07/12/2012   8:06   BROOKLYN    11230  40.619397 -73.969566
# 1           1  07/14/2012  14:15     QUEENS    11354  40.774412 -73.806785
# 2           2  07/14/2012  21:00     QUEENS    11372  40.753538 -73.886897
# 3           3  07/15/2012  11:00  MANHATTAN    10028  40.778815 -73.956083
# 4           4  07/06/2012   7:45     QUEENS    11101  40.744658 -73.948523
#
#                          LOCATION                    ON STREET NAME  \
# 0  POINT (-73.9695659 40.6193973)  OCEAN PARKWAY
# 1   POINT (-73.8067849 40.774412)  25 DRIVE
# 2  POINT (-73.8868974 40.7535377)  80 STREET
# 3  POINT (-73.9560828 40.7788145)  EAST 85 STREET
# 4  POINT (-73.9485231 40.7446585)  JACKSON AVENUE
#
#                   CROSS STREET NAME  ... CONTRIBUTING FACTOR VEHICLE 2  \
# 0  AVENUE L                          ...                   Unspecified
# ...

# %%
crashes['DATE']=pd.to_datetime(crashes['DATE'])

# %%
date_filt=((crashes['DATE']>=pd.to_datetime('01/01/2016')) & (crashes['DATE']<pd.to_datetime('1/1/2019') ))

# %%
clean_value=crashes[date_filt]
clean_value
# Out:
#         Unnamed: 0       DATE   TIME        BOROUGH ZIP CODE   LATITUDE  \
# 56429       133947 2018-12-09   9:48         QUEENS    11362  40.756992
# 56430       133948 2018-11-29  22:00         QUEENS    11369  40.767467
# 56431       133950 2018-12-11  16:50       BROOKLYN    11210  40.628647
# 56432       133951 2018-11-20   8:09          BRONX    10474  40.817110
# 56433       133952 2018-11-09  16:00       BROOKLYN    11238  40.679420
# 56434       133956 2018-11-14   8:30         QUEENS    11356  40.787785
# 56435       133957 2018-11-16   7:45      MANHATTAN    10011  40.743423
# 56436       133959 2018-12-12  18:20          BRONX    10459  40.822440
# 56437       133960 2018-12-28  20:30      MANHATTAN    10013  40.715584
# 56440       133964 2018-12-28  14:13          BRONX    10456  40.829290
# 56441       133969 2018-12-21   7:30         QUEENS    11103  40.758316
# 56444       133976 2018-12-13  19:10         QUEENS    11105  40.779747
# ...

# %%
clean_value.shape
# Out:
# (280391, 30)

# %%
clean_value['TIME']=pd.to_datetime(clean_value['TIME'])
# Out:
# C:\Users\789\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
 clean_value.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 280391 entries, 56429 to 356392
# Data columns (total 30 columns):
# Unnamed: 0                       280391 non-null int64
# DATE                             280391 non-null datetime64[ns]
# TIME                             280391 non-null datetime64[ns]
# BOROUGH                          280391 non-null object
# ZIP CODE                         280391 non-null object
# LATITUDE                         280391 non-null float64
# LONGITUDE                        280391 non-null float64
# LOCATION                         280391 non-null object
# ON STREET NAME                   280391 non-null object
# CROSS STREET NAME                280012 non-null object
# OFF STREET NAME                  200 non-null object
# NUMBER OF PERSONS INJURED        280386 non-null float64
# NUMBER OF PERSONS KILLED         280382 non-null float64
# NUMBER OF PEDESTRIANS INJURED    280391 non-null int64
# ...

# %%
clean_value.head()
# Out:
#        Unnamed: 0       DATE                TIME   BOROUGH ZIP CODE  \
# 56429      133947 2018-12-09 2019-09-13 09:48:00    QUEENS    11362
# 56430      133948 2018-11-29 2019-09-13 22:00:00    QUEENS    11369
# 56431      133950 2018-12-11 2019-09-13 16:50:00  BROOKLYN    11210
# 56432      133951 2018-11-20 2019-09-13 08:09:00     BRONX    10474
# 56433      133952 2018-11-09 2019-09-13 16:00:00  BROOKLYN    11238
#
#         LATITUDE  LONGITUDE                     LOCATION  \
# 56429  40.756992  -73.72966  POINT (-73.72966 40.756992)
# 56430  40.767467  -73.88187  POINT (-73.88187 40.767467)
# 56431  40.628647  -73.95207  POINT (-73.95207 40.628647)
# 56432  40.817110  -73.89204   POINT (-73.89204 40.81711)
# 56433  40.679420  -73.96823   POINT (-73.96823 40.67942)
#
#                          ON STREET NAME CROSS STREET NAME  ...  \
# 56429  MARATHON PARKWAY                         61 AVENUE  ...
# 56430  88 STREET                                23 AVENUE  ...
# ...

# %%
clean_value['TIME'].dt.hour==0
# Out:
# 56429     False
# 56430     False
# 56431     False
# 56432     False
# 56433     False
# 56434     False
# 56435     False
# 56436     False
# 56437     False
# 56440     False
# 56441     False
# 56444     False
# 56445      True
# 56446     False
# 56447     False
# 56448     False
# 56452     False
# 56456     False
# 56457     False
# 56458     False
# 56460     False
# 56462     False
# 56465     False
# 56466     False
# 56468     False
# 56469     False
# 56470     False
# 56471     False
# 56472     False
# 56473     False
#           ...
# 252561    False
# 252657    False
# 252672    False
# 252708    False
# 252760    False
# 252766    False
# 252773    False
# 252776    False
# 252867    False
# 252880    False
# 252890    False
# 252942    False
# 252946    False
# 252957    False
# 253045    False
# 253144    False
# 253176    False
# 253222    False
# 253255    False
# 253364    False
# 253402    False
# 253416    False
# 253493    False
# 253500    False
# ...

# %%
clean_value.to_csv(r'C:/Users/789/Desktop/Car_crashed_from_2016_to_2018.csv ')
